# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import r2_score,mean_squared_error
 
import warnings
warnings.filterwarnings('ignore')

data=pd.read_csv(r"D:\Mohamed\Creativa\practical\Creativa_25_AI(Data Science)\creativa_25_Ai_Elec_Tronics\Machine_learning\Salary_Data.csv")
data.describe()
# %matplotlib inline

# %%
plt.figure(figsize=(3,3))
sns.pairplot(data,x_vars=["YearsExperience"],y_vars=["Salary"],size=7,kind="scatter")
plt.xlabel("years")
plt.ylabel("salary")
plt.title("salary prediction")
plt.show()

# %%
x=data.iloc[:,:-1].values
y=data.iloc[:,1].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.8,random_state=10)

# %%
my_model=LinearRegression()
my_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = my_model.predict(x_test)
plt.scatter(x_test, y_test, color = 'grey')
plt.plot(x_test, y_pred, color = 'green')
plt.title('Salary & Experience ')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
#%%
plt.scatter(x_train, y_train, color = 'grey')
plt.plot(x_train, my_model.predict(x_train), color = 'green')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
c = [i for i in range(1,len(y_test)+1)]
plt.plot(c,y_test,color='r',linestyle='-')
plt.plot(c,y_pred,color='b',linestyle='-')
plt.xlabel('Salary')
plt.ylabel('index')
plt.title('Prediction')
plt.show()

# %%
mse = mean_squared_error(y_test,y_pred)
 
rsq = r2_score(y_test,y_pred)
y_hat = 9357 * 7 +  26089

# %%
import tkinter as tk

def add_to_list():
    try:
        x = int(entry.get())
        y_hat = 9357 * x + 26089
        result_label.config(text=f"Your Expected Salary: ${y_hat}", fg="green")
    except ValueError:
        result_label.config(text="Invalid input! Please enter a number.", fg="red")
    entry.delete(0, tk.END)

root = tk.Tk()
root.title("Salary Prediction App")

root.geometry("400x250")
root.resizable(False, False)

root.configure(bg="#f0f0f0")

title_label = tk.Label(root, text="Salary Prediction", font=("Arial", 24, "bold"), bg="#f0f0f0", fg="blue")
title_label.pack(pady=20)

input_frame = tk.Frame(root, bg="#f0f0f0")
input_frame.pack(pady=10)

entry_label = tk.Label(input_frame, text="Enter years of experience:", font=("Arial", 12), bg="#f0f0f0", fg="black")
entry_label.grid(row=0, column=0, padx=5, pady=5)

entry = tk.Entry(input_frame, width=20, font=("Arial", 14), bg="white", fg="black")
entry.grid(row=0, column=1, padx=5, pady=5)

predict_button = tk.Button(root, text="Predict Salary", command=add_to_list, font=("Arial", 14), bg="green", fg="white")
predict_button.pack(pady=15)

result_label = tk.Label(root, text="", font=("Arial", 14), bg="#f0f0f0", fg="black")
result_label.pack(pady=10)

root.mainloop()
